# %%
# !export PYTHONPATH=/data/hydro/hydro-2/code && \
python -m dan-main.run --arg_file './models/opt_Ross_noRain.txt'

# %%
# !export PYTHONPATH=/data/hydro/hydro-2/code && \
python -m dan-main.run --arg_file './models/opt_Ross_withRain.txt'

# %%
# !export PYTHONPATH=/data/hydro/hydro-2/code && \
python -m dan-main.run --arg_file './models/opt_Saratoga_noRain.txt'

# %%
# !export PYTHONPATH=/data/hydro/hydro-2/code && \
python -m dan-main.run --arg_file './models/opt_Saratoga_withRain.txt'

# %%
# !export PYTHONPATH=/data/hydro/hydro-2/code && \
python -m dan-main.run --arg_file './models/opt_SFC_noRain.txt'

# %%
# !export PYTHONPATH=/data/hydro/hydro-2/code && \
python -m dan-main.run --arg_file './models/opt_SFC_withRain.txt'

# %%
# !export PYTHONPATH=/data/hydro/hydro-2/code && \
python -m dan-main.run --arg_file './models/opt_UpperPen_noRain.txt'

# %%
# !export PYTHONPATH=/data/hydro/hydro-2/code && \
python -m dan-main.run --arg_file './models/opt_UpperPen_withRain.txt'
